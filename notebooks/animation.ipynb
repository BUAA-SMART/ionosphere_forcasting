# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from IPython.display import Image
import glob
from PIL import Image
from tqdm.notebook import tqdm

# %%
fig, ax = plt.subplots()
imgs = sorted(glob.glob("images/*"))
# imgs_pil = [Image.open(x) for x in tqdm(imgs)]
# ims = [[ax.imshow(x)] for x in imgs_pil]
# ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000, blit=True)
# plt.show()

# %%
# 使用 HTML 展示图片动画
html = '<img src="{0}" alt="{0}" width="600">'.format(imgs[0], '')
for file_name in imgs[1:]:
    html += '<img src="{0}" alt="{0}" width="600">'.format(file_name, '')

# 显示动画
HTML(html)
# Out:
# <img src="images/2000-01-01 01:00:00.png" alt="images/2000-01-01 01:00:00.png" width="600"><img src="images/2000-01-01 03:00:00.png" alt="images/2000-01-01 03:00:00.png" width="600"><img src="images/2000-01-01 05:00:00.png" alt="images/2000-01-01 05:00:00.png" width="600"><img src="images/2000-01-01 07:00:00.png" alt="images/2000-01-01 07:00:00.png" width="600"><img src="images/2000-01-01 09:00:00.png" alt="images/2000-01-01 09:00:00.png" width="600"><img src="images/2000-01-01 11:00:00.png" alt="images/2000-01-01 11:00:00.png" width="600"><img src="images/2000-01-01 13:00:00.png" alt="images/2000-01-01 13:00:00.png" width="600"><img src="images/2000-01-01 15:00:00.png" alt="images/2000-01-01 15:00:00.png" width="600"><img src="images/2000-01-01 17:00:00.png" alt="images/2000-01-01 17:00:00.png" width="600"><img src="images/2000-01-01 19:00:00.png" alt="images/2000-01-01 19:00:00.png" width="600"><img src="images/2000-01-01 21:00:00.png" alt="images/2000-01-01 21:00:00.png" width="60
# ...
